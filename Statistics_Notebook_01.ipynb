# %% [markdown]
# # Satatisitcs Notebooks - 01
# <br> Author: Denny P. Alappattu/ Created on: 04 July 2021

# %%
# !pip install matplotlib
# !pip install scipy 
# !pip install pandas
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.4.2-cp38-cp38-win_amd64.whl (7.1 MB)
# Collecting pillow>=6.2.0
#   Downloading Pillow-8.3.0-cp38-cp38-win_amd64.whl (2.3 MB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp38-cp38-win_amd64.whl (51 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\denny\anaconda3\envs\statienv\lib\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\denny\anaconda3\envs\statienv\lib\site-packages (from matplotlib) (2.8.1)
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting numpy>=1.16
#   Downloading numpy-1.21.0-cp38-cp38-win_amd64.whl (14.0 MB)
# Requirement already satisfied: six in c:\users\denny\anaconda3\envs\statienv\lib\site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Installing collected packages: pillow, numpy, kiwisolver, cycler, matplotlib
# Successfully installed cycler-0.10.0 kiwisolver-1.3.1 matplotlib-3.4.2 numpy-1.21.0 pillow-8.3.0
# Collecting scipy
#   Downloading scipy-1.7.0-cp38-cp38-win_amd64.whl (33.7 MB)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in c:\users\denny\anaconda3\envs\statienv\lib\site-packages (from scipy) (1.21.0)
# Installing collected packages: scipy
# Successfully installed scipy-1.7.0
# Collecting pandas
#   Downloading pandas-1.3.0-cp38-cp38-win_amd64.whl (10.2 MB)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\denny\anaconda3\envs\statienv\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\denny\anaconda3\envs\statienv\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\denny\anaconda3\envs\statienv\lib\site-packages (from pandas) (1.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\denny\anaconda3\envs\statienv\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Installing collected packages: pandas
# Successfully installed pandas-1.3.0

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\denny\anaconda3\envs\statienv\lib\site-packages (1.21.0)

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.11.1-py3-none-any.whl (285 kB)
# Requirement already satisfied: pandas>=0.23 in c:\users\denny\anaconda3\envs\statienv\lib\site-packages (from seaborn) (1.3.0)
# Requirement already satisfied: scipy>=1.0 in c:\users\denny\anaconda3\envs\statienv\lib\site-packages (from seaborn) (1.7.0)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\denny\anaconda3\envs\statienv\lib\site-packages (from seaborn) (3.4.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\denny\anaconda3\envs\statienv\lib\site-packages (from seaborn) (1.21.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\denny\anaconda3\envs\statienv\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\denny\anaconda3\envs\statienv\lib\site-packages (from matplotlib>=2.2->seaborn) (8.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\denny\anaconda3\envs\statienv\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\denny\anaconda3\envs\statienv\lib\site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\denny\anaconda3\envs\statienv\lib\site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: six in c:\users\denny\anaconda3\envs\statienv\lib\site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\denny\anaconda3\envs\statienv\lib\site-packages (from pandas>=0.23->seaborn) (2021.1)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.11.1

# %% [markdown]
# ## Import required libraries

# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style = "whitegrid")

# %% [markdown]
# ### Just a test of matplotlib.pyplot

# %%
plt.pcolor(np.random.randn(300,300))
plt.colorbar()
plt.show()

# %% [markdown]
# ### Numpy random number generators <br>
# Numpy provides three important functons to create random variables<br>
# These functions can be accessed from random module.
# * rand - generates randon numbers
# * randn - random numbers distributed in standard normal distribution
# * randint - random integers
# <br>
#
# Figures below are examples of these methods.

# %%
plt.figure(figsize=(12,3), dpi=150)
plt.subplot(1,3,1)
plt.hist(np.random.rand(10000)) # Example of "rand"
plt.title("rand")
plt.subplot(1,3,2)
plt.hist(np.random.randn(10000)) # Example of "randn"
plt.title("randn")
plt.subplot(1,3,3)
plt.hist(np.random.randint(low=1, high=100, size= 10000)) # Example of "randint"
plt.title("randint")
plt.show()

# %% [markdown]
# Use of function "choice"

# %%
np.random.choice(10,5,replace=True)
# Out:
# array([3, 8, 6, 6, 6])

# %% [markdown]
# ## "seed" and "RandomState"
